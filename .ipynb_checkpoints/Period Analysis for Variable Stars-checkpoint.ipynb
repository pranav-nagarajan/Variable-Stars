# %%
import os
import glob
import pickle
import itertools
import multiprocessing as mp

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from gatspy import periodic
from astropy.timeseries import LombScargle

from psearch_py import *

import pymc3 as pm
import theano.tensor as tt
import corner

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Preparing Dataset From Saha et al. (2017)

# %%
saha = pd.read_csv('392work2.tab', sep = '\s{5}', header = None, 
                   names = ['HJD-2400000.0', 'Magnitude', 'Uncertainty in Magnitude', 'Passband'], engine = 'python')
saha.info()
saha.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 370 entries, 0 to 369
# Data columns (total 4 columns):
# HJD-2400000.0               370 non-null float64
# Magnitude                   370 non-null float64
# Uncertainty in Magnitude    370 non-null float64
# Passband                    370 non-null float64
# dtypes: float64(4)
# memory usage: 11.6 KB
#    HJD-2400000.0  Magnitude  Uncertainty in Magnitude  Passband
# 0   56423.664062     27.769                     0.030       0.0
# 1   56423.812500     28.160                     0.029       0.0
# 2   56423.894531     28.089                     0.021       0.0
# 3   56424.718750     27.882                     0.024       0.0
# 4   56424.808594     28.105                     0.029       0.0

# %%
saha['Passband'] = saha['Passband'].replace({0.0 : 'u', 1.0 : 'g', 2.0 : 'r', 3.0 : 'i', 4.0: 'z'})
saha.to_csv('Periods/saha.csv', index = False)
saha.head()
# Out:
#    HJD-2400000.0  Magnitude  Uncertainty in Magnitude Passband
# 0   56423.664062     27.769                     0.030        u
# 1   56423.812500     28.160                     0.029        u
# 2   56423.894531     28.089                     0.021        u
# 3   56424.718750     27.882                     0.024        u
# 4   56424.808594     28.105                     0.029        u

# %%
plt.figure(figsize = (8, 5))
plt.title('Light Curve for RR Lyrae Star B1-392')
sns.scatterplot(x = 'HJD-2400000.0', y = 'Magnitude', data = saha, hue = 'Passband');

# %%
# Code from Saha et al. (2017)

hjd, mag, mag_err = saha["HJD-2400000.0"].values, saha["Magnitude"].values, saha["Uncertainty in Magnitude"].values
num_filts = pd.read_csv('392work2.tab', sep = '\s{5}', header = None, engine = 'python',
                        names = ['HJD-2400000.0', 'Magnitude', 'Uncertainty in Magnitude', 'Passband'])["Passband"].values
saha_periods, saha_lomb, saha_lk, saha_psi, saha_conf = periodpsi2_py(hjd, mag, mag_err, num_filts, 0.2, 0.02, 1)
# Out:
# periodpsi2: BEGIN
# periodpsi2: minimum and maximum periods:     0.20000176   346.62304690 days
# periodpsi2: number of period (frequency) samples:  173211   <----------
# periodpsi2:  68  observations  <----------
# scargle: DONE     5.481 seconds
# ctheta_slave: DONE     2.447 seconds
# periodpsi2_py:  1  of  1   (thresh loop)
# scargle: DONE     5.188 seconds
# ctheta_slave: DONE     0.716 seconds
# scargle: DONE     5.290 seconds
# ctheta_slave: DONE     0.650 seconds
# periodpsi2: END

# %%
# Plots in Saha et al. (2017)

saha_freqs = 1 / saha_periods

plt.figure()
plt.xlabel('Frequencies (1 / day)')
plt.ylabel(r'Power ($\Pi$)')
plt.title(f'Lomb-Scargle Periodogram - Saha et al. (2017)')
plt.plot(saha_freqs, saha_lomb);
    
plt.figure()
plt.xlabel('Frequencies (1 / day)')
plt.ylabel(r'Power ($2$ / $\Theta$)')
plt.title(f'Lafler-Kinman Periodogram - Saha et al. (2017)')
plt.plot(saha_freqs, 2 / saha_lk);

plt.figure()
plt.xlabel('Frequencies (1 / day)')
plt.ylabel(r'Power ($2\Pi$ / $\Theta$)')
plt.title(f'Hybrid Periodogram - Saha et al. (2017)')
plt.plot(saha_freqs, saha_psi);

# %% [markdown]
# # Computing the Hybrid Statistic

# %%
def phase_dispersion_minimization(times, magnitudes, uncertainties, periods, weighted = True):
    """Implements the formula for calculating the Lafler-Kinman statistic
    using weighted phase dispersion minimization."""
    
    lafler_kinmans = []
    for period in periods:
        
        folded = (times / period) % 1
        ordered = sorted(list(zip(folded, magnitudes, uncertainties)), key = lambda x: x[0])
        unzipped = [list(t) for t in zip(*ordered)]
        measurements, errors = unzipped[1], unzipped[2]
        wrap_measurements = [measurements[-1]] + measurements
        wrap_errors = [errors[-1]] + errors
        
        weights = []
        for i in range(1, len(wrap_errors)):
            weights.append(1 / (wrap_errors[i]**2 + wrap_errors[i - 1]**2))
        
        numerator = []
        for j in range(1, len(wrap_measurements)):
            difference = (wrap_measurements[j] - wrap_measurements[j - 1])**2
            if weighted:
                numerator.append(difference * weights[j - 1])
            else:
                numerator.append(difference)
        
        if weighted:
            weighted_mean = np.average(np.array(measurements), weights = np.array(weights))
            denominator = sum(weights)*sum((np.array(measurements) - weighted_mean)**2)
        else:
            denominator = sum((np.array(measurements) - np.mean(measurements))**2)
            
        lafler_kinman = sum(numerator) / denominator
        lafler_kinmans.append(lafler_kinman)

    return np.array(lafler_kinmans)


def lomb_scargle_analysis(times, magnitudes, uncertainties, min_period = 0.2, max_period = 1.5, 
                          version = "gatspy", weighted = True):
    """Generates the Lomb-Scargle periodogram for a variable star light curve."""
    
    fit_periods = np.linspace(min_period, max_period, 10000)
    
    if version == "gatspy":
        model = periodic.LombScargleFast(fit_period = True)
        model.optimizer.period_range = (min_period, max_period)
        if weighted:
            model.fit(times, magnitudes, uncertainties)
        else:
            model.fit(times, magnitudes)
        results = model.score(fit_periods)
    else:
        if weighted:
            astropy_model = LombScargle(times, magnitudes, uncertainties, normalization = 'psd', fit_mean = False)
            results = astropy_model.power(1 / fit_periods, method = 'slow')
        else:
            results = LombScargle(times, magnitudes, normalization='psd', fit_mean=False).power(1 / fit_periods, method='slow')
        
    return [fit_periods, results]


def hybrid_statistic(times, magnitudes, uncertainties, version = "gatspy", weighted = True):
    """Computes the hybrid statistic defined by Saha et al. (2017).
    Then, uses the hybrid statistic to find the best period."""
    
    periods, pi = lomb_scargle_analysis(times, magnitudes, uncertainties, version = version, weighted = weighted)
    theta = phase_dispersion_minimization(times, magnitudes, uncertainties, periods, weighted = weighted)
    hybrid_statistic = np.array(2 * pi / theta)
    best_period = periods[np.argmax(hybrid_statistic)]
    return [1 / periods, pi, 2 / theta, hybrid_statistic, best_period]

# %%
def filter_data(dataset, passband, **kwargs):
    """Returns light curve data for a specific star in a specific passband."""
    
    filtered = dataset[dataset["Passband"] == passband]
    
    for elem in kwargs.keys():
        try:
            filtered = filtered[filtered[elem.capitalize()] == kwargs.get(elem)]
        except KeyError as e:
            print(f"Dataset does not contain {e.args[0]} column. Attempting to filter based on additional keyword arguments.")
    
    epoch = filtered["HJD-2400000.0"].values
    magnitudes = filtered["Magnitude"].values
    magnitude_errors = filtered["Uncertainty in Magnitude"].values
    return epoch, magnitudes, magnitude_errors


def plot_periodogram(dataset, passband, version = "gatspy", weighted = True, plot = True, name = "Unknown", **kwargs):
    """Plots Lomb-Scargle, Lafler-Kinman, and hybrid periodograms for a variable star light curve."""
    
    epoch, magnitudes, magnitude_errors = filter_data(dataset, passband, **kwargs)
    frequencies, ls_powers, lk_powers, hybrid_powers, best_period = hybrid_statistic(epoch, magnitudes, magnitude_errors, 
                                                                                     version = version, weighted = weighted)
    
    if plot:
        
        if 'star' in kwargs.keys():
            name = kwargs.get('star')
        
        plt.figure()
        plt.xlabel('Frequencies (1 / day)')
        plt.ylabel(r'Power ($\Pi$)')
        plt.title(f'Lomb-Scargle Periodogram for {passband} Passband')
        plt.plot(frequencies, ls_powers, label = name)
        plt.legend()
    
        plt.figure()
        plt.xlabel('Frequencies (1 / day)')
        plt.ylabel(r'Power ($2$ / $\Theta$)')
        plt.title(f'Lafler-Kinman Periodogram for {passband} Passband')
        plt.plot(frequencies, lk_powers, label = name)
        plt.legend()
    
        plt.figure()
        plt.xlabel('Frequencies (1 / day)')
        plt.ylabel(r'Power ($2\Pi$ / $\Theta$)')
        plt.title(f'Hybrid Periodogram for {passband} Passband')
        plt.plot(frequencies, hybrid_powers, label = name)
        plt.legend();
    
    return [frequencies, ls_powers, lk_powers, hybrid_powers, best_period]

# %%
def find_best_period(dataset, version = "gatspy", weighted = True, plot = True, name = "Unknown", **kwargs):
    """Find the best period by averaging across the results from each passband."""
    
    interim = dataset
    if 'galaxy' in kwargs.keys():
        interim = interim[interim['Galaxy'] == kwargs.get('galaxy')]
    if 'star' in kwargs.keys():
        name = kwargs.get('star')
        interim = interim[interim['Star'] == name]
    
    passbands = interim["Passband"].unique()
    freqs, ls_powers, lk_powers, hybrid_powers, period = plot_periodogram(dataset, passbands[0], version = version, 
                                                                          weighted = weighted, plot = False, **kwargs)
    if version == "gatspy":
        print('\n')
    
    for passband in passbands[1:]:
        new_results = plot_periodogram(dataset, passband, version = version, weighted = weighted, plot = False, **kwargs)
        ls_powers = ls_powers + new_results[1]
        lk_powers = lk_powers + new_results[2]
        hybrid_powers = hybrid_powers + new_results[3]
        
        if version == "gatspy":
            print('\n')
        
    if plot:
        
        plt.figure()
        plt.xlabel('Frequencies (1 / day)')
        plt.ylabel(r'Power ($\Pi$)')
        plt.title('Lomb-Scargle Periodogram for All Passbands')
        plt.plot(freqs, ls_powers, label = name)
        plt.legend()
        
        plt.figure()
        plt.xlabel('Frequencies (1 / day)')
        plt.ylabel(r'Power ($2$ / $\Theta$)')
        plt.title('Lafler-Kinman Periodogram for All Passbands')
        plt.plot(freqs, lk_powers, label = name)
        plt.legend()
        
        plt.figure()
        plt.xlabel('Frequencies (1 / day)')
        plt.ylabel(r'Power ($2\Pi$ / $\Theta$)')
        plt.title('Hybrid Periodogram for All Passbands')
        plt.plot(freqs, hybrid_powers, label = name)
        plt.legend();
        
    best_ls_period = 1 / (freqs[np.argmax(ls_powers)])
    best_lk_period = 1 / (freqs[np.argmax(lk_powers)])
    best_hybrid_period = 1 / (freqs[np.argmax(hybrid_powers)])
    
    return [best_ls_period, best_lk_period, best_hybrid_period]

# %%
def phase_light_curve(best_period, dataset, passband, name = "Unknown", **kwargs):
    """Phases the variable star light curve based on the best period.
    Then, plots the phased light curve in the specified passband."""
    
    if 'star' in kwargs.keys():
        name = kwargs.get('star')
    
    times, magnitudes, magnitude_errors = filter_data(dataset, passband, **kwargs)
    phases = (times / best_period) % 1
    
    plt.figure()
    plt.title(f'Phased Light Curve in {passband} Passband')
    plt.xlabel('Phase')
    plt.ylabel('Magnitude')
    plt.scatter(phases, magnitudes, label = name)
    plt.errorbar(phases, magnitudes, yerr = magnitude_errors, linestyle = 'None')
    plt.legend();
    
    return phases

# %%
true_period = 0.5016240
g_period = plot_periodogram(saha, 'g', name = 'B1-392', version = 'astropy')[4];

print("\nBest Period in g Passband is", g_period)
print("True Period is", true_period, "Days")
# Out:
# Best Period in g Passband is 0.5016301630163016
# True Period is 0.501624 Days

# %%
best_period = find_best_period(saha, name = 'B1-392', version = 'astropy')[2];

print("Best Period is", best_period, "Days")
print("True Period is", true_period, "Days")
# Out:
# Best Period is 0.5016301630163016 Days
# True Period is 0.501624 Days

# %%
phases = phase_light_curve(best_period, saha, 'g', name = 'B1-392')

# %%
gatspy_freqs, gatspy_ls = hybrid_statistic(*filter_data(saha, "g"))[:2]
astropy_freqs, astropy_ls = hybrid_statistic(*filter_data(saha, "g"), version = "astropy")[:2]

comp_fig, comp_axs = plt.subplots(1, 3, figsize = (30, 5))
for ax in comp_axs:
    ax.set_xlabel('Frequencies (1 / day)')
    ax.set_ylabel(r'Power ($\Pi$)')

comp_axs[0].set_title('Lomb-Scargle Periodogram - Gatspy')
comp_axs[0].plot(gatspy_freqs, gatspy_ls);

comp_axs[1].set_title('Lomb-Scargle Periodogram - Astropy')
comp_axs[1].plot(astropy_freqs, astropy_ls);

comp_axs[2].set_title('Lomb Scargle Periodogram - Saha')
comp_axs[2].plot(saha_freqs, saha_lomb);
# Out:
# Finding optimal frequency:
#  - Estimated peak width = 0.00906
#  - Using 5 steps per peak; omega_step = 0.00181
#  - User-specified period range:  0.2 to 1.5
#  - Computing periods at 15022 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 1000 steps

# %%
astro_fig, astro_axs = plt.subplots(2, 2, figsize = (15, 10))
astro_axs = astro_axs.reshape(1, 4)[0]
for ax in astro_axs:
    ax.set_xlabel('Frequencies (1 / day)')
    ax.set_ylabel(r'Power ($\Pi$)')
    
normalizations = ["standard", "model", "log", "psd"]

for i in range(4):
    astro_model = LombScargle(*filter_data(saha, 'g')[:2], normalization = normalizations[i], fit_mean = False)
    astro_ls = astro_model.power(saha_freqs, method = 'slow')
    astro_axs[i].set_title(f"Lomb-Scargle Periodogram - {normalizations[i]}")
    astro_axs[i].plot(saha_freqs, astro_ls)

# %%
comp_fig, comp_axs = plt.subplots(1, 3, figsize = (30, 5))
for ax in comp_axs:
    ax.set_xlabel('Frequencies (1 / day)')
    ax.set_ylabel(r'Power ($\Pi$)')
    
astro_model = LombScargle(*filter_data(saha, 'g')[:2], normalization = 'psd', fit_mean = False)
astro_ls = astro_model.power(saha_freqs, method = 'slow')

comp_axs[0].set_title('Lomb-Scargle Periodogram - Astropy')
comp_axs[0].plot(saha_freqs, astro_ls);

comp_axs[1].set_title('Lomb-Scargle Periodogram - Saha')
comp_axs[1].plot(saha_freqs, saha_lomb);

comp_axs[2].set_title('Lomb Scargle Periodogram - Difference')
comp_axs[2].plot(saha_freqs, astro_ls - saha_lomb);

# %%
unweighted_lk = phase_dispersion_minimization(*filter_data(saha, 'g'), periods = 1 / saha_freqs, weighted = False)

lk_comp_fig, lk_comp_axs = plt.subplots(1, 3, figsize = (30, 5))
for ax in lk_comp_axs:
    ax.set_xlabel('Frequencies (1 / day)')
    ax.set_ylabel(r'Power ($2/\Theta$)')

lk_comp_axs[0].set_title('Lafler-Kinman Periodogram - Unweighted')
lk_comp_axs[0].plot(saha_freqs, 2 / unweighted_lk);

lk_comp_axs[1].set_title('Lafler-Kinman Periodogram - Saha')
lk_comp_axs[1].plot(saha_freqs, 2 / saha_lk);

lk_comp_axs[2].set_title('Lafler-Kinman Periodogram - Difference')
lk_comp_axs[2].plot(saha_freqs, 2 / unweighted_lk - 2 / saha_lk);

# %% [markdown]
# # Application to Andromeda Satellites

# %%
path = 'Andromeda/J_ApJ_850_137'
photometry_data = glob.glob(os.path.join(path, 'b2*.dat'))

hubble_names_1 = ['Galaxy', 'Star', 'HJD-2400000.0 (F475W)', 'Magnitude (F475W)', 'Uncertainty in Magnitude (F475W)',
                 'HJD-2400000.0 (F814W)', 'Magnitude (F814W)', 'Uncertainty in Magnitude (F814W)']

hubble_photometry = pd.concat((pd.read_csv(file, sep = '\s{1,}', header = None, names = hubble_names_1, engine = 'python') 
                               for file in photometry_data)).sort_values(by = ['Galaxy', 'Star']).dropna()

hubble_photometry['Star'] = hubble_photometry['Star'].str.replace('-', '')
hubble_F475W = hubble_photometry.iloc[:, :5]
hubble_F814W = pd.concat([hubble_photometry.iloc[:, :2], hubble_photometry.iloc[:, 5:]], axis = 1)

hubble_F475W['Passband'] = 'F475W'
hubble_F475W.rename({'HJD-2400000.0 (F475W)' : 'HJD-2400000.0', 'Magnitude (F475W)' : 'Magnitude', 
                    'Uncertainty in Magnitude (F475W)' : 'Uncertainty in Magnitude'}, axis = 1, inplace = True)

hubble_F814W['Passband'] = 'F814W'
hubble_F814W.rename({'HJD-2400000.0 (F814W)' : 'HJD-2400000.0', 'Magnitude (F814W)' : 'Magnitude', 
                    'Uncertainty in Magnitude (F814W)' : 'Uncertainty in Magnitude'}, axis = 1, inplace = True)

hubble_photometry = pd.concat([hubble_F475W, hubble_F814W], axis = 0).sort_values(by = ['Galaxy', 'Star'])
hubble_photometry.to_csv('Andromeda/andromeda.csv', index = False)
hubble_photometry.head()
# Out:
#   Galaxy  Star  HJD-2400000.0  Magnitude  Uncertainty in Magnitude Passband
# 0   AndI  V001   57266.425781     25.254                     0.089    F475W
# 1   AndI  V001   57266.500000     25.523                     0.056    F475W
# 2   AndI  V001   57266.691406     25.801                     0.041    F475W
# 3   AndI  V001   57266.765625     25.917                     0.064    F475W
# 4   AndI  V001   57267.417969     25.175                     0.036    F475W

# %%
pulsation_data = glob.glob(os.path.join(path, 'd4*.dat'))

hubble_names_2 = ['Galaxy', 'Star', 'RA (Hour)', 'RA (Minutes)', 'RA (Seconds)', 'Dec (Degrees)', 'Dec (Minutes)', 
                  'Dec (Seconds)', 'Period (Days)', 'Magnitude (F475W)', 'Amplitude (F475W)', 'Magnitude (F814W)', 
                  'Amplitude (F814W)', 'Magnitude (B-Band)', 'Amplitude (B-Band)', 'Magnitude (V-Band)', 'Amplitude (V-Band)', 
                  'Magnitude (Ic-Band)', 'Amplitude (Ic-Band)', 'Variable Type', 'Camera']

hubble_pulsation = pd.concat((pd.read_csv(file, sep = '\s{1,}', header = None, names = hubble_names_2, engine = 'python') 
                              for file in pulsation_data)).sort_values(by = ['Galaxy', 'Star'])

hubble_pulsation['Star'] = hubble_pulsation['Star'].str.replace('-', '')
hubble_pulsation.head()
# Out:
#   Galaxy  Star  RA (Hour)  RA (Minutes)  RA (Seconds)  Dec (Degrees)  \
# 0   AndI  V001          0            45         9.233             37
# 1   AndI  V002          0            45         9.646             37
# 2   AndI  V003          0            45         9.819             37
# 3   AndI  V004          0            45        10.116             37
# 4   AndI  V005          0            45        10.429             37
#
#    Dec (Minutes)  Dec (Seconds)  Period (Days)  Magnitude (F475W)  ...    \
# 0             58          47.19          0.569             25.532  ...
# 1             59          48.86          0.567             25.505  ...
# 2             59          32.31          0.296             25.329  ...
# 3             58          44.43          0.598             25.322  ...
# 4             58          56.47          0.585             25.557  ...
#
#    Magnitude (F814W)  Amplitude (F814W)  Magnitude (B-Band)  \
# 0             24.692              0.574              25.657
# 1             24.737              0.358              25.613
# 2             24.831              0.091              25.398
# 3             24.607              0.699              25.415
# 4             24.733              0.608              25.680
#
#    Amplitude (B-Band)  Magnitude (V-Band)  Amplitude (V-Band)  \
# 0               1.137              25.266               0.915
# 1               0.669              25.251               0.436
# 2               0.392              25.159               0.207
# 3               1.605              25.103               0.949
# 4               0.864              25.276               0.660
#
#    Magnitude (Ic-Band)  Amplitude (Ic-Band)  Variable Type Camera
# 0               24.677                0.580           RRab   WFC3
# 1               24.719                0.360           RRab   WFC3
# 2               24.819                0.097            RRc   WFC3
# 3               24.599                0.669           RRab   WFC3
# 4               24.722                0.576           RRab   WFC3
#
# [5 rows x 21 columns]

# %%
hubble_periods = hubble_pulsation[['Galaxy', 'Star', 'Period (Days)']]
hubble_periods.info()

hubble_periods.to_csv('Andromeda/andromeda_periods.csv', index = False)
hubble_periods.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 895 entries, 0 to 89
# Data columns (total 3 columns):
# Galaxy           895 non-null object
# Star             895 non-null object
# Period (Days)    895 non-null float64
# dtypes: float64(1), object(2)
# memory usage: 28.0+ KB
#   Galaxy  Star  Period (Days)
# 0   AndI  V001          0.569
# 1   AndI  V002          0.567
# 2   AndI  V003          0.296
# 3   AndI  V004          0.598
# 4   AndI  V005          0.585

# %%
best_period_AndI_V001_F475W = plot_periodogram(hubble_photometry, 'F475W', star = 'V001', galaxy = 'AndI', 
                                               version = 'astropy')[4];
print(f"\nBest Period in F475W Passband is {best_period_AndI_V001_F475W} Days")
# Out:
# Best Period in F475W Passband is 0.5732673267326733 Days

# %%
best_period_AndI_V001 = find_best_period(hubble_photometry, star = 'V001', galaxy = 'AndI', version = 'astropy')[2];
print(f"\nBest Period is {best_period_AndI_V001} Days")
# Out:
# Best Period is 0.5732673267326733 Days

# %%
hubble_best_periods = np.array(pickle.load(open("Andromeda/andromeda_periods.pkl", "rb")))[:, 2:].T[0]
hubble_periods['Best Period (Days)'] = hubble_best_periods
display(hubble_periods.head())

print(np.average(np.abs(hubble_periods.iloc[:, 3] - hubble_periods.iloc[:, 2])))
# Out:
#   Galaxy  Star  Period (Days)  Best Period (Days)
# 0   AndI  V001          0.569            0.573338
# 1   AndI  V002          0.567            0.569529
# 2   AndI  V003          0.296            0.293432
# 3   AndI  V004          0.598            0.611714
# 4   AndI  V005          0.585            0.585168
# 0.01590177187805398

# %%
hubble_data = hubble_photometry.copy()
hubble_data['SNR'] = 1 / (10**(hubble_data['Uncertainty in Magnitude'] / 2.5) - 1)

hubble_pass = hubble_data[['Galaxy', 'Star', 'Passband', 'SNR']].groupby(['Galaxy', 'Star', 'Passband']).mean().reset_index()
sns.boxplot(data = hubble_pass, x = 'Passband', y = 'SNR')
plt.title('Distribution of SNR by Passband');

# %%
hubble_data = hubble_data[['Galaxy', 'Star', 'SNR']]
hubble_data = hubble_data.groupby(['Galaxy', 'Star']).mean().reset_index()

hubble_diff = np.abs(hubble_periods['Period (Days)'] - hubble_periods['Best Period (Days)']).values
hubble_data['Difference'] = hubble_diff
display(hubble_data.head())

sns.scatterplot(data = hubble_data, x = 'SNR', y = 'Difference')
plt.title('Dependence of Absolute Difference in Periods on \nAverage Signal-to-Noise Ratio');
# Out:
#   Galaxy  Star        SNR  Difference
# 0   AndI  V001  16.668341    0.004338
# 1   AndI  V002  16.522371    0.002529
# 2   AndI  V003  17.591154    0.002568
# 3   AndI  V004  19.156996    0.013714
# 4   AndI  V005  16.011397    0.000168

# %%
weighted_hubble = hubble_periods.copy()
weighted_hubble = weighted_hubble.rename({'Best Period (Days)' : 'Computed Period (Days)', 
                                          'Period (Days)' : 'Reported Period (Days)'}, axis = 1)
weighted_hubble['SNR'] = hubble_data['SNR']

hubble_bins = [0, 20, 40, 60]
hubble_labels = ['0-20', '20-40', '40-60']
weighted_hubble['Average SNR'] = pd.cut(weighted_hubble['SNR'], bins = hubble_bins, labels = hubble_labels)

sns.scatterplot(data = weighted_hubble, x = 'Reported Period (Days)', y = 'Computed Period (Days)', 
                hue = 'Average SNR', hue_order = hubble_labels)
plt.title('Comparison of Computed and Reported Periods')
plt.xlabel('Reported Period (Days)')
plt.ylabel('Computed Period (Days)');

# %%
sorted_hubble_diff = hubble_data.sort_values(by = 'Difference', ascending = False)
print(len(hubble_data[hubble_data['Difference'] < 0.02]), len(hubble_data))
sorted_hubble_diff.head()
# Out:
# 833 895
#         Galaxy  Star        SNR  Difference
# 791      AndXV  V117  30.844981    1.569190
# 180       AndI  V181  21.514139    1.069599
# 535      AndII  V234  21.440665    0.894920
# 280       AndI  V281  16.636277    0.543420
# 814  AndXXVIII  V010  21.534011    0.521592

# %%
for i in range(10):
    test_galaxy, test_star = sorted_hubble_diff.iloc[i, 0], sorted_hubble_diff.iloc[i, 1]
    gal_star_row = hubble_periods[(hubble_periods['Galaxy'] == test_galaxy) & (hubble_periods['Star'] == test_star)]
    reported_period, hybrid_period = gal_star_row.iloc[0, 2], gal_star_row.iloc[0, 3]
    
    display(gal_star_row)    
    hubble_report = phase_light_curve(reported_period, hubble_photometry, 'F475W', star = test_star, galaxy = test_galaxy)
    hubble_best = phase_light_curve(hybrid_period, hubble_photometry, 'F475W', star = test_star, galaxy = test_galaxy)
    plt.show();
# Out:
#     Galaxy  Star  Period (Days)  Best Period (Days)
# 116  AndXV  V117          2.186             0.61681
#     Galaxy  Star  Period (Days)  Best Period (Days)
# 180   AndI  V181          0.355            1.424599
#     Galaxy  Star  Period (Days)  Best Period (Days)
# 233  AndII  V234          0.487             1.38192
#     Galaxy  Star  Period (Days)  Best Period (Days)
# 280   AndI  V281          0.536             1.07942
#       Galaxy  Star  Period (Days)  Best Period (Days)
# 9  AndXXVIII  V010           0.51            1.031592
#   Galaxy  Star  Period (Days)  Best Period (Days)
# 0  AndXV  V001          0.503            0.996297
#     Galaxy  Star  Period (Days)  Best Period (Days)
# 112   AndI  V113          0.477             0.94973
#    Galaxy  Star  Period (Days)  Best Period (Days)
# 44   AndI  V045          0.429            0.764479
#    Galaxy  Star  Period (Days)  Best Period (Days)
# 35   AndI  V036          0.571            0.283552
#     Galaxy  Star  Period (Days)  Best Period (Days)
# 169  AndII  V170          0.571            0.287868

# %% [markdown]
# # Application to Sculptor Dwarf Galaxy

# %%
sculptor_path_1 = os.path.join('Sculptor/J_MNRAS_462_4349', 'table4.dat')

sculptor_names_1 = ['Star', 'Name 1', 'Name 2', 'RA (Hour)', 'RA (Minutes)', 'RA (Seconds)', 'Dec (Degrees)', 'Dec (Minutes)', 
                    'Dec (Seconds)', 'Period (Days)', 'Uncertainty Flag on Period', 'Mean Magnitude (B)', 'Mean Magnitude (V)', 
                    'Mean Magnitude (I)', 'Amplitude (B)', 'Amplitude (V)', 'Amplitude (I)', 'Quality Flag 1', 'Quality Flag 2',
                    'Variable Type']

sculptor_pulsation = pd.read_csv(sculptor_path_1, sep = '\s{1,}', header = None, names = sculptor_names_1, engine = 'python', 
                                 usecols = [i for i in range(21)])

sculptor_pulsation = sculptor_pulsation.replace({"--" : np.nan, "----" : np.nan, "-----" : np.nan})
sculptor_pulsation.head()
# Out:
#           Star Name 1 Name 2  RA (Hour)  RA (Minutes)  RA (Seconds)  \
# 0  scl-CEMV001   V461    NaN          0            55         21.02
# 1  scl-CEMV002    NaN    NaN          0            56          9.15
# 2  scl-CEMV005    NaN    NaN          0            56         38.94
# 3  scl-CEMV006    NaN    NaN          0            56         48.78
# 4  scl-CEMV008    NaN    NaN          0            57          4.83
#
#    Dec (Degrees)  Dec (Minutes)  Dec (Seconds)  Period (Days)  \
# 0            -33             41            1.5       0.420876
# 1            -33             29           20.1       0.305970
# 2            -33             24           32.4       0.309746
# 3            -33             31           16.3       0.332111
# 4            -33             45           20.6       0.281318
#
#   Uncertainty Flag on Period  Mean Magnitude (B)  Mean Magnitude (V)  \
# 0                         ::              20.150              19.830
# 1                        NaN              20.326              20.163
# 2                        NaN              20.260              20.086
# 3                        NaN              20.333              20.117
# 4                        NaN              20.357              20.047
#
#    Mean Magnitude (I)  Amplitude (B)  Amplitude (V)  Amplitude (I)  \
# 0              19.460          0.900          0.630          0.000
# 1              19.840          0.298          0.254          0.168
# 2              19.778          0.494          0.359          0.165
# 3              19.738          0.568          0.479          0.401
# 4              19.570          0.881          0.576          0.485
#
#    Quality Flag 1  Quality Flag 2 Variable Type
# 0               1               0          RRab
# 1               0               1           RRc
# 2               0               1           RRc
# 3               0               1           RRc
# 4               2               0           RRc

# %%
sculptor_path_2 = os.path.join('Sculptor/J_MNRAS_462_4349', 'table2.dat')

sculptor_names_2 = ['Star', 'HJD-2400000.0 (B)', 'Magnitude (B)', 'Uncertainty in Magnitude (B)',
                  'HJD-2400000.0 (V)', 'Magnitude (V)', 'Uncertainty in Magnitude (V)', 
                  'HJD-2400000.0 (I)', 'Magnitude (I)', 'Uncertainty in Magnitude (I)']

sculptor_photometry = pd.read_csv(sculptor_path_2, sep = '\s{1,}', header = None, names = sculptor_names_2, engine = 'python')

sculptor_B = sculptor_photometry.iloc[:, :4]
sculptor_V = pd.concat([sculptor_photometry.iloc[:, :1], sculptor_photometry.iloc[:, 4:7]], axis = 1)
sculptor_I = pd.concat([sculptor_photometry.iloc[:, :1], sculptor_photometry.iloc[:, 7:]], axis = 1)

sculptor_B['Passband'] = 'B'
sculptor_B.rename({'HJD-2400000.0 (B)' : 'HJD-2400000.0', 'Magnitude (B)' : 'Magnitude', 
                   'Uncertainty in Magnitude (B)' : 'Uncertainty in Magnitude'}, axis = 1, inplace = True)

sculptor_V['Passband'] = 'V'
sculptor_V.rename({'HJD-2400000.0 (V)' : 'HJD-2400000.0', 'Magnitude (V)' : 'Magnitude', 
                   'Uncertainty in Magnitude (V)' : 'Uncertainty in Magnitude'}, axis = 1, inplace = True)

sculptor_I['Passband'] = 'I'
sculptor_I.rename({'HJD-2400000.0 (I)' : 'HJD-2400000.0', 'Magnitude (I)' : 'Magnitude', 
                   'Uncertainty in Magnitude (I)' : 'Uncertainty in Magnitude'}, axis = 1, inplace = True)

sculptor_photometry = pd.concat([sculptor_B, sculptor_V, sculptor_I], axis = 0)
sculptor_photometry = sculptor_photometry.replace("---", np.nan).dropna()
sculptor_photometry = sculptor_photometry.astype({"HJD-2400000.0" : 'float64', "Magnitude" : 'float64', 
                                                  "Uncertainty in Magnitude" : 'float64'})

sculptor_photometry = sculptor_photometry[sculptor_photometry["Star"].isin(sculptor_pulsation["Star"].unique())]

sculptor_photometry.to_csv('Sculptor/sculptor.csv', index = False)
sculptor_photometry.head()
# Out:
#           Star  HJD-2400000.0  Magnitude  Uncertainty in Magnitude Passband
# 0  scl-CEMV001     54734.6147     19.636                     0.011        B
# 1  scl-CEMV001     54734.6561     19.809                     0.017        B
# 2  scl-CEMV001     54734.7185     20.070                     0.026        B
# 3  scl-CEMV001     54734.7516     20.314                     0.311        B
# 4  scl-CEMV001     54734.7742     20.220                     0.010        B

# %%
sculptor_periods = sculptor_pulsation[["Star", "Period (Days)"]]
sculptor_periods.info()

sculptor_periods.to_csv('Sculptor/sculptor_periods.csv', index = False)
sculptor_periods.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 536 entries, 0 to 535
# Data columns (total 2 columns):
# Star             536 non-null object
# Period (Days)    536 non-null float64
# dtypes: float64(1), object(1)
# memory usage: 8.5+ KB
#           Star  Period (Days)
# 0  scl-CEMV001       0.420876
# 1  scl-CEMV002       0.305970
# 2  scl-CEMV005       0.309746
# 3  scl-CEMV006       0.332111
# 4  scl-CEMV008       0.281318

# %%
best_period_V001_V = plot_periodogram(sculptor_photometry, 'V', star = 'scl-CEMV001')[4];
print(f"\nBest Period in V Passband is {best_period_V001_V} Days")
# Out:
# Finding optimal frequency:
#  - Estimated peak width = 0.00343
#  - Using 5 steps per peak; omega_step = 0.000685
#  - User-specified period range:  0.2 to 1.5
#  - Computing periods at 39742 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 1000 steps
#
# Best Period in V Passband is 0.4247924792479248 Days

# %%
best_period_V001 = find_best_period(sculptor_photometry, star = 'scl-CEMV001', version = 'astropy')[2];
print(f"\nBest Period is {best_period_V001} Days")
# Out:
# Best Period is 0.4247924792479248 Days

# %%
sculptor_best_periods = np.array(pickle.load(open("Sculptor/sculptor_periods.pkl", "rb")))[:, 2:].T[0]
sculptor_periods['Best Period (Days)'] = sculptor_best_periods
display(sculptor_periods.head())

print(np.average(np.abs(sculptor_periods.iloc[:, 2] - sculptor_periods.iloc[:, 1])))
# Out:
#           Star  Period (Days)  Best Period (Days)
# 0  scl-CEMV001       0.420876            0.423615
# 1  scl-CEMV002       0.305970            0.305002
# 2  scl-CEMV005       0.309746            0.308837
# 3  scl-CEMV006       0.332111            0.333667
# 4  scl-CEMV008       0.281318            0.569724
# 0.06903777024551402

# %%
good_sculptor_stars = sculptor_pulsation[sculptor_pulsation['Quality Flag 2'] == 1]['Star'].unique()
good_sculptor_periods = sculptor_periods[sculptor_periods['Star'].isin(good_sculptor_stars)]
display(good_sculptor_periods.head())

print(np.average(np.abs(good_sculptor_periods.iloc[:, 2] - good_sculptor_periods.iloc[:, 1])))
# Out:
#           Star  Period (Days)  Best Period (Days)
# 1  scl-CEMV002       0.305970            0.305002
# 2  scl-CEMV005       0.309746            0.308837
# 3  scl-CEMV006       0.332111            0.333667
# 5  scl-CEMV010       0.405639            0.405636
# 6  scl-CEMV012       0.370277            0.369964
# 0.0329464940923218

# %%
binned_data = sculptor_photometry.copy()
binned_data['SNR'] = 1 / (10**(binned_data['Uncertainty in Magnitude'] / 2.5) - 1)

bin_pass = binned_data[['Star', 'Passband', 'SNR']].groupby(['Star', 'Passband']).mean().reset_index()
sns.boxplot(data = bin_pass, x = 'Passband', y = 'SNR')
plt.title('Distribution of SNR by Passband');

# %%
binned_data = binned_data[['Star', 'SNR']]
binned_data = binned_data.groupby('Star').mean().reset_index()
binned_data['Difference'] = np.abs(sculptor_periods['Period (Days)'] - sculptor_periods['Best Period (Days)'])
binned_data['Quality'] = sculptor_pulsation['Quality Flag 2']
display(binned_data.head())

sns.scatterplot(data = binned_data, x = 'SNR', y = 'Difference', hue = 'Quality')
plt.title('Dependence of Absolute Difference in Periods on \nAverage Signal-to-Noise Ratio');
# Out:
#           Star        SNR  Difference  Quality
# 0  scl-CEMV001  63.244520    0.002739        0
# 1  scl-CEMV002  86.582400    0.000968        1
# 2  scl-CEMV005  89.196736    0.000909        1
# 3  scl-CEMV006  79.890738    0.001556        1
# 4  scl-CEMV008  80.483498    0.288405        0

# %%
weighted_comp = sculptor_periods.copy()
weighted_comp = weighted_comp.rename({'Period (Days)' : 'Reported Period (Days)', 
                                      'Best Period (Days)' : 'Computed Period (Days)'}, axis = 1)
weighted_comp['SNR'] = binned_data['SNR']
weighted_comp['Quality'] = binned_data['Quality']

cut_bins = [10, 40, 70, 100]
cut_labels = ['10-40', '40-70', '70-100']
weighted_comp['Average SNR'] = pd.cut(weighted_comp['SNR'], bins = cut_bins, labels = cut_labels)

# sns.scatterplot(data = weighted_comp, x = 'Reported Period (Days)', y = 'Computed Period (Days)', 
#                 hue = 'Average SNR', hue_order = cut_labels)
sns.scatterplot(data = weighted_comp, x = 'Reported Period (Days)', y = 'Computed Period (Days)', hue = 'Quality')

plt.title('Comparison of Computed and Reported Periods')
plt.xlabel('Reported Period (Days)')
plt.ylabel('Computed Period (Days)');

# %%
sorted_diff = binned_data.sort_values(by = 'Difference', ascending = False)
print(len(binned_data[binned_data['Difference'] < 0.01]), len(binned_data))
display(sorted_diff.merge(sculptor_pulsation[['Star', 'Uncertainty Flag on Period']], on = 'Star').head(10))
# Out:
# 439 536
#           Star        SNR  Difference  Quality Uncertainty Flag on Period
# 0  scl-CEMV610  91.939951    1.365894        0                         ::
# 1  scl-CEMV066  80.754553    1.084707        0                          :
# 2  scl-CEMV393  79.899304    1.078712        0                        NaN
# 3  scl-CEMV570  75.458405    1.075999        1                        NaN
# 4  scl-CEMV258  73.885090    0.977541        0                          :
# 5  scl-CEMV310  53.214164    0.915582        0                        NaN
# 6  scl-CEMV381  75.947471    0.911047        0                        NaN
# 7  scl-CEMV328  53.713318    0.880811        1                        NaN
# 8  scl-CEMV520  34.407304    0.841151        0                        NaN
# 9  scl-CEMV291  46.473891    0.826505        0                        NaN

# %%
good_sorted_diff = binned_data[binned_data['Quality'] == 1].sort_values(by = 'Difference', ascending = False)
print(len(good_sorted_diff[good_sorted_diff['Difference'] < 0.01]), len(good_sorted_diff))
display(good_sorted_diff.merge(sculptor_pulsation[['Star', 'Uncertainty Flag on Period']], on = 'Star').head(10))
# Out:
# 269 298
#           Star        SNR  Difference  Quality Uncertainty Flag on Period
# 0  scl-CEMV570  75.458405    1.075999        1                        NaN
# 1  scl-CEMV328  53.713318    0.880811        1                        NaN
# 2  scl-CEMV165  73.814502    0.622209        1                        NaN
# 3  scl-CEMV268  61.013498    0.584594        1                        NaN
# 4  scl-CEMV220  58.561692    0.573660        1                        NaN
# 5  scl-CEMV543  71.975019    0.525811        1                        NaN
# 6  scl-CEMV535  71.661934    0.515579        1                        NaN
# 7  scl-CEMV167  59.465219    0.510427        1                        NaN
# 8  scl-CEMV097  86.353553    0.506631        1                        NaN
# 9  scl-CEMV046  74.308083    0.506097        1                        NaN

# %%
for i in range(10):
    # test_star_sculptor = sorted_diff.iloc[i, 0]
    test_star_sculptor = good_sorted_diff.iloc[i, 0]
    star_row = sculptor_periods[sculptor_periods['Star'] == test_star_sculptor]
    reported_sculptor_period, hybrid_sculptor_period = star_row.iloc[0, 1], star_row.iloc[0, 2]
    
    display(star_row)    
    sculptor_report = phase_light_curve(reported_sculptor_period, sculptor_photometry, 'V', star = test_star_sculptor)
    sculptor_best = phase_light_curve(hybrid_sculptor_period, sculptor_photometry, 'V', star = test_star_sculptor)
    plt.show();
# Out:
#             Star  Period (Days)  Best Period (Days)
# 487  scl-CEMV570       0.361301              1.4373
#             Star  Period (Days)  Best Period (Days)
# 280  scl-CEMV328       0.560364            1.441174
#             Star  Period (Days)  Best Period (Days)
# 140  scl-CEMV165       0.604788            1.226997
#             Star  Period (Days)  Best Period (Days)
# 229  scl-CEMV268       0.292296            0.876891
#             Star  Period (Days)  Best Period (Days)
# 189  scl-CEMV220        0.57366            1.147319
#             Star  Period (Days)  Best Period (Days)
# 464  scl-CEMV543       0.525815            1.051626
#             Star  Period (Days)  Best Period (Days)
# 459  scl-CEMV535       0.511489            1.027068
#             Star  Period (Days)  Best Period (Days)
# 142  scl-CEMV167       0.519319            1.029746
#            Star  Period (Days)  Best Period (Days)
# 82  scl-CEMV097       0.506631            1.013262
#            Star  Period (Days)  Best Period (Days)
# 35  scl-CEMV046       0.510038            1.016135

# %%
saha_test = sculptor_photometry[sculptor_photometry["Star"] == "scl-CEMV006"].replace({"B" : 0, "V" : 1, "I" : 2})
psearch_py(saha_test["HJD-2400000.0"].values, saha_test["Magnitude"].values, saha_test["Uncertainty in Magnitude"].values, 
           saha_test["Passband"].values.astype(np.float64), ["B", "V", "I"], 0.2, 0.02)
# Out:
# psearch: BEGIN =====================================================
#
# REFERENCE:
#
# Saha, A., & Vivas, A. K. 2017, Astronomical Journal, 154, 231;
#     "A Hybrid Algorithm for Period Analysis from Multiband Data with
#     Sparse and Irregular Sampling for Arbitrary Light-curve Shapes"
# IDL CODE (Abhijit Saha):
#     https://github.com/AbhijitSaha/Psearch
# PYTHON/CYTHON/C CODE (Kenenth Mighell):
#     https://github.com/AbhijitSaha/Psearch/tree/master/psearch_py
#
# MODULE:
#     C:\Pranav\UCB_Sophomore_Year\Weisz Group Research\Variable-Stars\psearch_py.py
#     [psearch_py (0.23.6)  mode: pure Python  (*** slow ***) ]
#
# psearch:  B  filter
# periodpsi2: BEGIN
# periodpsi2: minimum and maximum periods:     0.20000041  1320.94270000 days
# periodpsi2: number of period (frequency) samples:  660371   <----------
# periodpsi2:  28  observations  <----------
# scargle: DONE    20.852 seconds
# ctheta_slave: DONE     1.342 seconds
# periodpsi2_py:  1  of  1   (thresh loop)
# scargle: DONE    19.341 seconds
# ctheta_slave: DONE     1.410 seconds
# scargle: DONE    20.248 seconds
# ctheta_slave: DONE     1.480 seconds
# periodpsi2: END
# TABLE: BEGIN
# rank   -------Period [days]------      Psi    index  Frequency  Thresh
#  1      0.50075541 +-  0.00000095      4.93   263690   1.996983    0.23
#  2      0.48701042 +-  0.00000090      4.73   271135   2.053344    0.45
#  3      0.33371128 +-  0.00000042      4.48   395734   2.996602    0.36
#  4      0.48711817 +-  0.00000090      4.43   271075   2.052890    0.45
#  5      0.48371827 +-  0.00000089      4.40   272981   2.067319    0.35
#  6      0.33371381 +-  0.00000042      4.31   395731   2.996580    0.35
#  7      0.32779280 +-  0.00000041      4.30   402881   3.050708    0.46
#  8      0.48424493 +-  0.00000089      4.12   272684   2.065071    0.45
#  9      0.32774400 +-  0.00000041      4.09   402941   3.051162    0.56
# 10      0.33216222 +-  0.00000042      4.04   397580   3.010577    0.34
# TABLE: END
# psearch:  V  filter
# periodpsi2: BEGIN
# periodpsi2: minimum and maximum periods:     0.20000041  1320.94270000 days
# periodpsi2: number of period (frequency) samples:  660371   <----------
# periodpsi2:  33  observations  <----------
# scargle: DONE    19.834 seconds
# ctheta_slave: DONE     1.503 seconds
# periodpsi2_py:  1  of  1   (thresh loop)
# scargle: DONE    19.897 seconds
# ctheta_slave: DONE     1.507 seconds
# scargle: DONE    19.242 seconds
# ctheta_slave: DONE     1.470 seconds
# periodpsi2: END
# TABLE: BEGIN
# rank   -------Period [days]------      Psi    index  Frequency  Thresh
#  1      0.49390821 +-  0.00000092      2.75   267347   2.024668    0.27
#  2      0.48707686 +-  0.00000090      2.43   271098   2.053064    0.30
#  3      0.49391191 +-  0.00000092      2.43   267345   2.024653    0.23
#  4      0.49405045 +-  0.00000092      2.30   267270   2.024085    0.10
#  5      0.49402643 +-  0.00000092      2.28   267283   2.024183    0.20
#  6      0.49404491 +-  0.00000092      2.24   267273   2.024107    0.12
#  7      0.48708584 +-  0.00000090      2.21   271093   2.053026    0.28
#  8      0.49390267 +-  0.00000092      2.20   267350   2.024690    0.25
#  9      0.49402274 +-  0.00000092      2.18   267285   2.024198    0.21
# 10      0.33366913 +-  0.00000042      2.14   395784   2.996981    0.06
# TABLE: END
# psearch:  I  filter
# periodpsi2: BEGIN
# periodpsi2: minimum and maximum periods:     0.20000041  1320.94270000 days
# periodpsi2: number of period (frequency) samples:  660371   <----------
# periodpsi2:  14  observations  <----------
# scargle: DONE    18.948 seconds
# ctheta_slave: DONE     0.953 seconds
# periodpsi2_py:  1  of  1   (thresh loop)
# scargle: DONE    26.152 seconds
# ctheta_slave: DONE     1.291 seconds
# scargle: DONE    19.041 seconds
# ctheta_slave: DONE     0.954 seconds
# periodpsi2: END
# TABLE: BEGIN
# rank   -------Period [days]------      Psi    index  Frequency  Thresh
#  1      0.23385394 +-  0.00000021      0.17   564758   4.276173    0.01
#  2      0.21461260 +-  0.00000017      0.17   615401   4.659559    0.02
#  3      0.23090699 +-  0.00000020      0.17   571967   4.330748    0.01
#  4      0.70155810 +-  0.00000186      0.16   188187   1.425399    0.02
#  5      0.21473959 +-  0.00000017      0.16   615037   4.656803    0.03
#  6      0.21986726 +-  0.00000018      0.15   600691   4.548199    0.03
#  7      0.22252291 +-  0.00000019      0.15   593521   4.493919    0.02
#  8      0.21484123 +-  0.00000017      0.15   614746   4.654600    0.03
#  9      0.24989552 +-  0.00000024      0.15   528498   4.001672    0.04
# 10      0.22525732 +-  0.00000019      0.15   586315   4.439367    0.02
# TABLE: END
#
# ========== ALL FILTERS ==========
#
# TABLE: BEGIN
# rank   -------Period [days]------      Psi    index  Frequency  Thresh
#  1      0.33216222 +-  0.00000042      5.60   397580   3.010577    0.40
#  2      0.48424493 +-  0.00000089      5.58   272684   2.065071    0.60
#  3      0.48371827 +-  0.00000089      5.52   272981   2.067319    0.50
#  4      0.50075541 +-  0.00000095      5.47   263690   1.996983    0.31
#  5      0.33216472 +-  0.00000042      5.34   397577   3.010555    0.44
#  6      0.33211211 +-  0.00000042      5.20   397640   3.011031    0.40
#  7      0.48701042 +-  0.00000090      5.15   271135   2.053344    0.52
#  8      0.33371381 +-  0.00000042      5.15   395731   2.996580    0.54
#  9      0.33211044 +-  0.00000042      5.14   397642   3.011047    0.41
# 10      0.33371128 +-  0.00000042      5.14   395734   2.996602    0.58
# TABLE: END
#
# Reference:
#
# Saha, A., & Vivas, A. K. 2017, Astronomical Journal, 154, 231;
#     "A Hybrid Algorithm for Period Analysis from Multiband Data with
#     Sparse and Irregular Sampling for Arbitrary Light-curve Shapes"
# IDL CODE (Abhijit Saha):
#     https://github.com/AbhijitSaha/Psearch
# PYTHON/CYTHON/C CODE (Kenenth Mighell):
#     https://github.com/AbhijitSaha/Psearch/tree/master/psearch_py
#
# MODULE:
#     C:\Pranav\UCB_Sophomore_Year\Weisz Group Research\Variable-Stars\psearch_py.py
#     [psearch_py (0.23.6)  mode: pure Python  (*** slow ***) ]
#
# psearch: END =======================================================
# (array([1.32094270e+03, 1.30786406e+03, 1.29504186e+03, ...,
#         2.00001014e-01, 2.00000712e-01, 2.00000409e-01]),
#  array([[0.00521007, 0.00716458, 0.00884693, ..., 0.04936826, 0.04082595,
#          0.03461308],
#         [0.02439224, 0.01748266, 0.01471674, ..., 0.00171398, 0.00077742,
#          0.00056475],
#         [0.03780797, 0.03782823, 0.03772467, ..., 0.00633489, 0.00617518,
#          0.00519455]]),
#  array([[0.07330463, 0.07402669, 0.07340407, ..., 0.43125453, 0.50248841,
#          0.4964206 ],
#         [0.11920059, 0.12140074, 0.11656171, ..., 0.03401782, 0.0327806 ,
#          0.03266354],
#         [0.0191859 , 0.01930889, 0.01936007, ..., 0.03257664, 0.03182851,
#          0.02342999]]))

# %% [markdown]
# # Investigating the Effects of Sparsity and Noise

# %%
def simulate_sparsity_and_noise(dataset, passband, sparsity = 1.0, signal_to_noise = 0, **kwargs):
    """Simulates sparsity and noise in the light curve data of a specific star in a specific passband."""
    
    times, magnitudes, errors = filter_data(dataset, passband, **kwargs)
    simulated = pd.DataFrame({"HJD-2400000.0" : times, "Magnitude" : magnitudes, 
                              "Uncertainty in Magnitude" : errors, "Passband" : passband})
    
    if sparsity != 1.0:
        simulated = simulated.sample(frac = sparsity)
    
    if signal_to_noise != 0:
        simulated["Uncertainty in Magnitude"] = 2.5 * np.log10(1 + 1 / signal_to_noise)
        noise = [np.random.normal(0, error) for error in simulated["Uncertainty in Magnitude"].values]
        simulated["Magnitude"] = simulated["Magnitude"] + noise
    
    return simulated


def simulate_best_period(dataset, sparsity = 1.0, signal_to_noise = 0, version = "gatspy", weighted = True, 
                         plot = False, name = "Unknown", lc = False, **kwargs):
    """Simulates sparsity and noise in the light curve data of a specific star.
    Then, determines the effect on the calculation of the best period."""
    
    passbands = dataset["Passband"].unique()
    initial = simulate_sparsity_and_noise(dataset, passbands[0], sparsity, signal_to_noise, **kwargs)
    
    for passband in passbands[1:]:
        
        new_data = simulate_sparsity_and_noise(dataset, passband, sparsity, signal_to_noise, **kwargs)
        initial = pd.concat([initial, new_data], axis = 0)
    
    best_periods = find_best_period(initial, version = version, weighted = weighted, plot = plot, name = name, **kwargs)
    
    if lc:
        phases = phase_light_curve(best_periods[2], initial, passbands[1], name = name, **kwargs)
        
    return best_periods

# %%
sparse_results_lomb = pickle.load(open("Periods/sparse_noisy_periods.pkl", "rb"))[:, :, 0:1].T[0]
sparse_results_lomb = np.array([np.average(lst) for lst in sparse_results_lomb])
sparse_results_lomb
# Out:
# array([0.42235708, 0.50159314, 0.50159002, 0.50159002, 0.59035048,
#        0.50160094, 0.46007852, 0.4143919 , 0.25024784, 0.41646256,
#        0.37924449, 0.45729493, 0.33332075, 0.62637982, 0.35743079,
#        0.38718237])

# %%
sparse_results_lk = pickle.load(open("Periods/sparse_noisy_periods.pkl", "rb"))[:, :, 1:2].T[0]
sparse_results_lk = np.array([np.average(lst) for lst in sparse_results_lk])
sparse_results_lk
# Out:
# array([0.89397268, 0.62192806, 0.50162902, 0.50162902, 0.71790412,
#        0.62219508, 0.50162902, 0.50162902, 0.42689829, 0.62429486,
#        0.75243584, 0.50154322, 0.29814058, 0.58149037, 0.47199158,
#        0.69544535])

# %%
sparse_results_hybrid = pickle.load(open("Periods/sparse_noisy_periods.pkl", "rb"))[:, :, 2:].T[0]
sparse_results_hybrid = np.array([np.average(lst) for lst in sparse_results_hybrid])
sparse_results_hybrid
# Out:
# array([0.59544601, 0.5016259 , 0.50162902, 0.50162902, 0.64337983,
#        0.50172366, 0.50162902, 0.50162902, 0.57525889, 0.46150386,
#        0.50162902, 0.5016337 , 0.29526859, 0.4258068 , 0.35918321,
#        0.35033818])

# %%
best_periods = list(zip(sparse_results_lomb, sparse_results_lk, sparse_results_hybrid))
best_periods
# Out:
# [(0.4223570835708357, 0.8939726797267974, 0.5954460144601446),
#  (0.5015931359313592, 0.6219280592805927, 0.5016258962589625),
#  (0.5015900159001588, 0.5016290162901629, 0.5016290162901629),
#  (0.5015900159001588, 0.5016290162901629, 0.5016290162901629),
#  (0.5903504835048349, 0.7179041190411906, 0.643379833798338),
#  (0.5016009360093601, 0.6221950819508195, 0.5017236572365724),
#  (0.46007852078520783, 0.5016290162901629, 0.5016290162901629),
#  (0.4143919039190391, 0.5016290162901629, 0.5016290162901629),
#  (0.25024784247842474, 0.42689828898288984, 0.5752588925889258),
#  (0.41646256462564635, 0.6242948629486296, 0.4615038550385502),
#  (0.37924449244492436, 0.7524358443584438, 0.501629016290163),
#  (0.45729493294932966, 0.5015432154321543, 0.5016336963369633),
#  (0.3333207532075321, 0.298140581405814, 0.29526859268592687),
#  (0.6263798237982381, 0.5814903749037491, 0.42580679806798083),
#  (0.3574307943079431, 0.4719915799157991, 0.3591832118321183),
#  (0.38718237182371823, 0.6954453544535444, 0.3503381833818338)]

# %%
sparsities = np.array([1.0, 0.5, 0.25, 0.125])
sn_ratios = np.array([1, 10, 100, 1000])
combinations = itertools.product(sparsities, sn_ratios)

parameters = pd.DataFrame(list(combinations), columns = ["Sparsity", "Signal-to-Noise"])
results = pd.DataFrame(best_periods, columns = ["Lomb-Scargle", "Lafler-Kinman", "Hybrid Method"])
results_table = pd.concat([parameters, results], axis = 1)
results_table
# Out:
#     Sparsity  Signal-to-Noise  Lomb-Scargle  Lafler-Kinman  Hybrid Method
# 0      1.000                1      0.422357       0.893973       0.595446
# 1      1.000               10      0.501593       0.621928       0.501626
# 2      1.000              100      0.501590       0.501629       0.501629
# 3      1.000             1000      0.501590       0.501629       0.501629
# 4      0.500                1      0.590350       0.717904       0.643380
# 5      0.500               10      0.501601       0.622195       0.501724
# 6      0.500              100      0.460079       0.501629       0.501629
# 7      0.500             1000      0.414392       0.501629       0.501629
# 8      0.250                1      0.250248       0.426898       0.575259
# 9      0.250               10      0.416463       0.624295       0.461504
# 10     0.250              100      0.379244       0.752436       0.501629
# 11     0.250             1000      0.457295       0.501543       0.501634
# 12     0.125                1      0.333321       0.298141       0.295269
# 13     0.125               10      0.626380       0.581490       0.425807
# 14     0.125              100      0.357431       0.471992       0.359183
# 15     0.125             1000      0.387182       0.695445       0.350338

# %%
results_table.pivot(index = "Sparsity", columns = "Signal-to-Noise")
# Out:
#                 Lomb-Scargle                               Lafler-Kinman  \
# Signal-to-Noise         1         10        100       1000          1
# Sparsity
# 0.125               0.333321  0.626380  0.357431  0.387182      0.298141
# 0.250               0.250248  0.416463  0.379244  0.457295      0.426898
# 0.500               0.590350  0.501601  0.460079  0.414392      0.717904
# 1.000               0.422357  0.501593  0.501590  0.501590      0.893973
#
#                                               Hybrid Method            \
# Signal-to-Noise      10        100       1000          1         10
# Sparsity
# 0.125            0.581490  0.471992  0.695445      0.295269  0.425807
# 0.250            0.624295  0.752436  0.501543      0.575259  0.461504
# 0.500            0.622195  0.501629  0.501629      0.643380  0.501724
# 1.000            0.621928  0.501629  0.501629      0.595446  0.501626
#
#
# Signal-to-Noise      100       1000
# Sparsity
# 0.125            0.359183  0.350338
# 0.250            0.501629  0.501634
# 0.500            0.501629  0.501629
# 1.000            0.501629  0.501629

# %%
for sparsity in sparsities:
    filtered_results = results_table[results_table["Sparsity"] == sparsity]
    fig, axs = plt.subplots(1, 3, figsize = (25, 5))
    for ax in axs:
        ax.set_title(f'Dependence of Best Period on S-N Ratio of Data \n at Sparsity of {sparsity}')
        ax.set_xlabel('Log of S-N Ratio')
        ax.set_ylabel('Best Period (Days)')
    axs[0].scatter(np.log(sn_ratios), filtered_results["Lomb-Scargle"], label = 'Lomb-Scargle Periods', color = 'r')
    axs[1].scatter(np.log(sn_ratios), filtered_results["Lafler-Kinman"], label = 'Lafler-Kinman Periods', color = 'g')
    axs[2].scatter(np.log(sn_ratios), filtered_results["Hybrid Method"], label = 'Hybrid Periods', color = 'b')
    for ax in axs:
        ax.axhline(y = 0.501624, color = 'gold', linestyle = '-')
        ax.legend();

# %%
for sn in sn_ratios:
    filtered_results = results_table[results_table["Signal-to-Noise"] == sn]
    fig, axs = plt.subplots(1, 3, figsize = (25, 5))
    for ax in axs:
        ax.set_title(f'Dependence of Best Period on Sparsity of Data \n at SN-Ratio of {sn}')
        ax.set_xlabel('Sparsity')
        ax.set_ylabel('Best Period (Days)')
    axs[0].scatter(sparsities, filtered_results["Lomb-Scargle"], label = 'Lomb-Scargle Periods', color = 'r')
    axs[1].scatter(sparsities, filtered_results["Lafler-Kinman"], label = 'Lafler-Kinman Periods', color = 'g')
    axs[2].scatter(sparsities, filtered_results["Hybrid Method"], label = 'Hybrid Periods', color = 'b')
    for ax in axs:
        ax.axhline(y = 0.501624, color = 'gold', linestyle = '-')
        ax.legend();

# %%
dense_noisy = simulate_best_period(saha, sparsity = 0.75, signal_to_noise = 10, version = 'astropy',
                                   plot = True, name = "Sparsity of 0.75 and S-N Ratio of 10", lc = True)

# %%
sparse_signal = simulate_best_period(saha, sparsity = 0.1, signal_to_noise = 1000, version = 'astropy',
                                     plot = True, name = "Sparsity of 0.1 and S-N Ratio of 1000", lc = True)

# %% [markdown]
# # Application to Neeley et al. (2019)

# %%
field_path_1 = os.path.join('Milky Way/Neeley', 'periods.txt')

field_names_1 = ['Name', 'Constellation', 'Period (Days)', 'Max HJD', 'Z', 'Class', 'Blazhko', 'Metallicity', ]

field_pulsation = pd.read_csv(field_path_1, sep = '\s{1,}', header = None, names = field_names_1, engine = 'python', 
                              usecols = [i for i in range(8)])

field_pulsation['Star'] = field_pulsation['Name'] + ' ' + field_pulsation['Constellation']
field_pulsation = field_pulsation.drop(['Name', 'Constellation', 'Z', 'Blazhko', 'Max HJD'], axis = 1)

field_pulsation = field_pulsation[['Star', 'Period (Days)', 'Class', 
                                   'Metallicity']].sort_values(['Star']).reset_index().drop(['index'], axis = 1)

field_pulsation.to_csv('Milky Way/field_pulsation.csv', index = False)
field_pulsation.head()
# Out:
#      Star  Period (Days) Class  Metallicity
# 0  AB UMa       0.599581  RRab        -0.49
# 1  AE Boo       0.314890   RRc        -1.39
# 2  AM Tuc       0.405802   RRc        -1.49
# 3  AN Ser       0.522071  RRab        -0.07
# 4  AP Ser       0.340830   RRc        -1.58

# %%
field_periods = field_pulsation[['Star', 'Period (Days)']]
field_periods.info()

field_periods.to_csv('Milky Way/field_periods.csv', index = False)
field_periods.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 2 columns):
# Star             55 non-null object
# Period (Days)    55 non-null float64
# dtypes: float64(1), object(1)
# memory usage: 960.0+ bytes
#      Star  Period (Days)
# 0  AB UMa       0.599581
# 1  AE Boo       0.314890
# 2  AM Tuc       0.405802
# 3  AN Ser       0.522071
# 4  AP Ser       0.340830

# %%
field_path_2 = os.path.join('Milky Way/Neeley', 'photometry.txt')

field_names_2 = ['Name', 'Constellation', 'Passband', 'Magnitude', 'Uncertainty in Magnitude', 'Zero Point', 'HJD-2400000.0', 
                 'Phase', 'Ref']

field_photometry = pd.read_csv(field_path_2, sep = '\s{1,}', header = None, names = field_names_2, engine = 'python')

field_photometry['Star'] = field_photometry['Name'] + ' ' + field_photometry['Constellation']
field_photometry = field_photometry[(field_photometry["Ref"] == 0)]

field_photometry = field_photometry.drop(['Name', 'Constellation', 'Zero Point', 'Ref', 'Phase'], axis = 1)
field_photometry = field_photometry[['Star', 'HJD-2400000.0', 'Magnitude', 'Uncertainty in Magnitude', 'Passband']]

field_photometry = field_photometry.sort_values(by = ['Star', 'Passband']).reset_index().drop(['index'], axis = 1)
field_photometry = field_photometry.groupby(['Star', 'Passband']).filter(lambda sf: len(sf) > 10)

field_photometry.to_csv('Milky Way/field.csv', index = False)
field_photometry.head()
# Out:
#      Star  HJD-2400000.0  Magnitude  Uncertainty in Magnitude Passband
# 0  AB UMa     56754.4846     11.244                     0.023        B
# 1  AB UMa     56792.2093     11.138                     0.022        B
# 2  AB UMa     56792.2115     11.149                     0.022        B
# 3  AB UMa     56792.2137     11.148                     0.022        B
# 4  AB UMa     56792.2159     11.148                     0.022        B

# %%
field_path_3 = os.path.join('Milky Way/Neeley', 'parallaxes.txt')

field_names_3 = ['Name', 'Constellation', 'ID', 'RA', 'Dec', 'Parallax (mas)', 'Parallax Error (mas)', 
                 'G Magnitude', 'Uncertainty in G Magnitude', 'BP Magnitude', 'Uncertainty in BP Magnitude',
                 'RP Magnitude', 'Uncertainty in RP Magnitude', 'E(B - V)']

field_parallax = pd.read_csv(field_path_3, sep = '\s{1,}', header = None, names = field_names_3, engine = 'python', 
                             usecols = [i for i in range(14)])

field_parallax['Star'] = field_parallax['Name'] + ' ' + field_parallax['Constellation']
field_parallax = field_parallax.drop(['Name', 'Constellation', 'ID', 'RA', 'Dec'], axis = 1)
field_parallax = field_parallax[['Star', 'Parallax (mas)', 'Parallax Error (mas)', 'E(B - V)']]

field_parallax = field_parallax.sort_values('Star').reset_index().drop('index', axis = 1)
field_parallax['Parallax (mas)'] = field_parallax['Parallax (mas)'].astype(float) + 0.03

field_parallax.to_csv('Milky Way/field_parallax.csv', index = False)
field_parallax.head()
# Out:
#      Star  Parallax (mas)  Parallax Error (mas)  E(B - V)
# 0  AB UMa            1.01                  0.03     0.022
# 1  AE Boo            1.17                  0.04     0.023
# 2  AM Tuc            0.57                  0.03     0.023
# 3  AN Ser            0.98                  0.04     0.040
# 4  AP Ser            0.78                  0.04     0.042

# %%
field_path_4 = os.path.join('Milky Way/Neeley', 'magnitudes.txt')

field_names_4 = ['Name', 'Constellation', 'Mean U Magnitude', 'Uncertainty in Mean U Magnitude', 'Mean B Magnitude', 
                 'Uncertainty in Mean B Magnitude', 'Mean V Magnitude', 'Uncertainty in Mean V Magnitude',
                 'Mean R Magnitude', 'Uncertainty in Mean R Magnitude', 'Mean I Magnitude', 'Uncertainty in Mean I Magnitude']

field_mags = pd.read_csv(field_path_4, sep = '\s{1,}', header = None, names = field_names_4, engine = 'python', 
                         usecols = [i for i in range(12)])

field_mags['Star'] = field_mags['Name'] + ' ' + field_mags['Constellation']
field_mags = field_mags.iloc[:, 4:]
field_mags = field_mags[['Star', 'Mean B Magnitude', 'Uncertainty in Mean B Magnitude', 'Mean V Magnitude', 
                         'Uncertainty in Mean V Magnitude', 'Mean I Magnitude', 'Uncertainty in Mean I Magnitude']]
field_mags = field_mags.sort_values('Star').reset_index().drop('index', axis = 1)

field_mags.to_csv('Milky Way/field_magnitudes.csv', index = False)
field_mags.head()
# Out:
#      Star  Mean B Magnitude  Uncertainty in Mean B Magnitude  \
# 0  AB UMa            11.359                            0.009
# 1  AE Boo            10.887                            0.009
# 2  AM Tuc            11.918                            0.006
# 3  AN Ser            11.321                            0.008
# 4  AP Ser            11.368                            0.008
#
#    Mean V Magnitude  Uncertainty in Mean V Magnitude  Mean I Magnitude  \
# 0            10.912                            0.009            10.342
# 1            10.640                            0.009            10.254
# 2            11.626                            0.006            11.188
# 3            10.935                            0.008            10.446
# 4            11.129                            0.008            10.765
#
#    Uncertainty in Mean I Magnitude
# 0                            0.009
# 1                            0.009
# 2                            0.006
# 3                            0.008
# 4                            0.008

# %%
best_period_rr = find_best_period(field_photometry, star = 'AB UMa', version = 'astropy')[2];
print(f"\nBest Period is {best_period_rr} Days")
# Out:
# Best Period is 0.5995299529952995 Days

# %%
field_best_periods = np.array(pickle.load(open("Milky Way/field_periods.pkl", "rb")))[:, 2:].T[0]
field_periods['Best Period (Days)'] = field_best_periods
display(field_periods.head())
# Out:
#      Star  Period (Days)  Best Period (Days)
# 0  AB UMa       0.599581            0.599468
# 1  AE Boo       0.314890            0.852308
# 2  AM Tuc       0.405802            0.405818
# 3  AN Ser       0.522071            0.522078
# 4  AP Ser       0.340830            0.340830

# %%
sns.scatterplot(data = field_periods, x = 'Period (Days)', y = 'Best Period (Days)', hue = field_pulsation['Class'])
plt.title('Comparison of Computed and Reported Periods')
plt.xlabel('Reported Period (Days)')
plt.ylabel('Computed Period (Days)');

# %%
diff = np.abs(field_periods["Period (Days)"] - field_periods["Best Period (Days)"])
print(np.average(diff))

print(len(field_periods[diff <= 0.01]), "out of", len(field_periods), "RR Lyrae stars have matching periods.")
# Out:
# 0.15706387248087555
# 37 out of 55 RR Lyrae stars have matching periods.

# %% [markdown]
# # Application to Crater II

# %%
crater_path_1 = os.path.join('Crater II', 'crater_pulsation.csv')

crater_names_1 = ['Star', 'RA', 'Dec', 'Period (Days)', 'Mean Magnitude (B)', 'Mean Amplitude (B)', 'Mean Magnitude (V)', 
                  'Mean Amplitude (V)', 'Mean Magnitude (I)', 'Mean Amplitude (I)', 'Type', 'Period (Joo)', 'Notes']

crater_pulsation = pd.read_csv(crater_path_1, header = None, names = crater_names_1)
crater_pulsation.head()
# Out:
#     Star            RA           Dec Period (Days) Mean Magnitude (B)  \
# 0  V001   11:48:46.94   −18:37:28.8     0.7633058             20.925
# 1  V002   11:48:59.49   −18:10: 9.8     0.6043024             21.432
# 2  V003   11:48:38.77   −18:31:40.2     0.6009024             21.217
# 3  V004   11:48:51.17   −18:16:34.1     0.4091809             21.260
# 4  V005   11:48:51.89   −18:31:56.7     0.5989511             21.227
#
#   Mean Amplitude (B) Mean Magnitude (V) Mean Amplitude (V) Mean Magnitude (I)  \
# 0             0.984             20.553              0.820             19.950
# 1             0.913             20.966              0.759             20.406
# 2             1.019             20.920              0.834             20.349
# 3             0.477             20.906              0.470             20.403
# 4             1.229             20.904              0.966             20.335
#
#   Mean Amplitude (I)       Type Period (Joo) Notes
# 0             0.503   Peculiar       0.7633    NaN
# 1             0.546       RRab       0.6053    NaN
# 2             0.515       RRab       0.6009    NaN
# 3             0.218        RRc       0.4189    NaN
# 4             0.575       RRab       0.5989    NaN

# %%
crater_periods = crater_pulsation[['Star', 'Period (Days)']]
crater_periods['Star'] = crater_periods['Star'].str.strip()
crater_periods['Period (Days)'] = crater_periods['Period (Days)'].str.strip()
crater_periods = crater_periods.astype({"Star" : 'str', "Period (Days)" : 'float64'})
crater_periods.info()
display(crater_periods.head())
crater_periods.to_csv('Crater II/crater_periods.csv', index = False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 2 columns):
# Star             37 non-null object
# Period (Days)    37 non-null float64
# dtypes: float64(1), object(1)
# memory usage: 672.0+ bytes
#    Star  Period (Days)
# 0  V001       0.763306
# 1  V002       0.604302
# 2  V003       0.600902
# 3  V004       0.409181
# 4  V005       0.598951

# %%
crater_path_2 = os.path.join('Crater II', 'crater_photometry.csv')

crater_names_2 = ['Star', 'HJD-2400000.0 (B)', 'Magnitude (B)', 'Uncertainty in Magnitude (B)',
                  'HJD-2400000.0 (V)', 'Magnitude (V)', 'Uncertainty in Magnitude (V)', 
                  'HJD-2400000.0 (I)', 'Magnitude (I)', 'Uncertainty in Magnitude (I)']

crater_photometry = pd.read_csv(crater_path_2, header = None, names = crater_names_2)
crater_photometry.head()
# Out:
#    Star HJD-2400000.0 (B) Magnitude (B)  Uncertainty in Magnitude (B)  \
# 0  V001         57538.373        20.862                         0.192
# 1  V001        57538.4249        21.214                         0.028
# 2  V001         57539.428        21.318                         0.036
# 3  V001        57540.4039        20.486                         0.018
# 4  V001        57540.4368        20.606                         0.021
#
#   HJD-2400000.0 (V) Magnitude (V)  Uncertainty in Magnitude (V)  \
# 0        57538.4276        20.737                         0.023
# 1        57540.4067        20.227                         0.016
# 2        57540.4395        20.306                         0.014
# 3         57541.403        20.631                         0.021
# 4        57541.4296        20.647                         0.018
#
#   HJD-2400000.0 (I) Magnitude (I)  Uncertainty in Magnitude (I)
# 0        57538.4312        20.069                         0.039
# 1        57540.4102        19.839                         0.028
# 2        57540.4137        19.769                         0.030
# 3         57540.443        19.812                         0.024
# 4        57541.4077        19.998                         0.024

# %%
crater_B = crater_photometry.iloc[:, :4]
crater_V = pd.concat([crater_photometry.iloc[:, :1], crater_photometry.iloc[:, 4:7]], axis = 1)
crater_I = pd.concat([crater_photometry.iloc[:, :1], crater_photometry.iloc[:, 7:]], axis = 1)

crater_B['Passband'] = 'B'
crater_B.rename({'HJD-2400000.0 (B)' : 'HJD-2400000.0', 'Magnitude (B)' : 'Magnitude', 
                   'Uncertainty in Magnitude (B)' : 'Uncertainty in Magnitude'}, axis = 1, inplace = True)

crater_V['Passband'] = 'V'
crater_V.rename({'HJD-2400000.0 (V)' : 'HJD-2400000.0', 'Magnitude (V)' : 'Magnitude', 
                   'Uncertainty in Magnitude (V)' : 'Uncertainty in Magnitude'}, axis = 1, inplace = True)

crater_I['Passband'] = 'I'
crater_I.rename({'HJD-2400000.0 (I)' : 'HJD-2400000.0', 'Magnitude (I)' : 'Magnitude', 
                   'Uncertainty in Magnitude (I)' : 'Uncertainty in Magnitude'}, axis = 1, inplace = True)

crater_photometry = pd.concat([crater_B, crater_V, crater_I], axis = 0)
crater_photometry = crater_photometry.replace("---", np.nan).dropna()
crater_photometry = crater_photometry.astype({"HJD-2400000.0" : 'float64', "Magnitude" : 'float64', 
                                                  "Uncertainty in Magnitude" : 'float64'})

crater_photometry = crater_photometry[['Star', 'HJD-2400000.0', 'Magnitude', 'Uncertainty in Magnitude', 'Passband']]

display(crater_photometry.head())
crater_photometry.to_csv('Crater II/crater.csv', index = False)
# Out:
#    Star  HJD-2400000.0  Magnitude  Uncertainty in Magnitude Passband
# 0  V001     57538.3730     20.862                     0.192        B
# 1  V001     57538.4249     21.214                     0.028        B
# 2  V001     57539.4280     21.318                     0.036        B
# 3  V001     57540.4039     20.486                     0.018        B
# 4  V001     57540.4368     20.606                     0.021        B

# %%
best_period_crater_V003 = find_best_period(crater_photometry, star = 'V003', version = 'astropy')[2];
print(f"\nBest Period is {best_period_crater_V003} Days")
# Out:
# Best Period is 0.7545054505450546 Days

# %%
phase_light_curve(best_period_crater_V003, crater_photometry, passband = 'V', star = 'V003');

# %%
crater_path_3 = os.path.join('Crater II', 'vivas_periods.csv')

crater_names_3 = ['Star', 'RA', 'Dec', 'Period (Days)', 'N_g', 'Delta_g', 'Mean Magnitude (g)', 
                  'N_i', 'Delta_i', 'Mean Magnitude (i)', 'E(B - V)', 'Type']

crater_pulsation_new = pd.read_csv(crater_path_3, header = None, names = crater_names_3)
crater_pulsation_new.head()
# Out:
#   Star          RA         Dec Period (Days)   N_g Delta_g Mean Magnitude (g)  \
# 0  V1   177.19560   −18.62472       0.76343   157    1.12              20.76
# 1  V2   177.24786   −18.16946       0.60442   125    1.17              21.08
# 2  V3   177.16149   −18.52788       0.60078   156    1.06              21.00
# 3  V4   177.21320   −18.27621       0.41651   155    0.80              21.00
# 4  V5   177.21616   −18.53250       0.59900   152    1.29              21.08
#
#     N_i Delta_i Mean Magnitude (i) E(B - V) Type
# 0  158    0.61              20.37    0.034   AC
# 1  125    0.51              20.78    0.032   ab
# 2  157    0.53              20.73    0.033   ab
# 3  158    0.37              20.73    0.032    d
# 4  157    0.61              20.75    0.033   ab

# %%
crater_periods_new = crater_pulsation_new[['Star', 'Period (Days)', 'Type']]

crater_periods_new['Star'] = crater_periods_new['Star'].str.strip()
add_zeros = np.array(['0' * elem for elem in np.array(3 - crater_periods_new['Star'].str[1:].str.len())])
crater_periods_new['Star'] = (crater_periods_new['Star'].str[0] + add_zeros + crater_periods_new['Star'].str[1:])

crater_periods_new['Period (Days)'] = crater_periods_new['Period (Days)'].str.strip()
crater_periods_new['Type'] = crater_periods_new['Type'].str.strip()
crater_periods_new = crater_periods_new.astype({"Period (Days)" : 'float64'})

crater_periods_new.info()
display(crater_periods_new.head())
crater_periods_new.to_csv('Crater II/crater_periods_new.csv', index = False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130 entries, 0 to 129
# Data columns (total 3 columns):
# Star             130 non-null object
# Period (Days)    130 non-null float64
# Type             130 non-null object
# dtypes: float64(1), object(2)
# memory usage: 3.1+ KB
#    Star  Period (Days) Type
# 0  V001        0.76343   AC
# 1  V002        0.60442   ab
# 2  V003        0.60078   ab
# 3  V004        0.41651    d
# 4  V005        0.59900   ab

# %%
crater_path_4 = os.path.join('Crater II', 'Table2.mrt')

crater_names_4 = ['Star', 'HJD-2400000.0', 'Magnitude', 'Uncertainty in Magnitude', 'Passband']

crater_photometry_new = pd.read_csv(crater_path_4, sep = '\s{1,}', header = None, names = crater_names_4, engine = 'python')

crater_photometry_new['Star'] = crater_photometry_new['Star'].str.strip()
add_zeros = np.array(['0' * elem for elem in np.array(3 - crater_photometry_new['Star'].str[1:].str.len())])
crater_photometry_new['Star'] = (crater_photometry_new['Star'].str[0] + add_zeros + crater_photometry_new['Star'].str[1:])

crater_photometry_new = crater_photometry_new.astype({"HJD-2400000.0" : 'float64', "Magnitude" : 'float64', 
                                                      "Uncertainty in Magnitude" : 'float64'})

crater_photometry_new.info()
display(crater_photometry_new.head())
crater_photometry_new.to_csv('Crater II/crater.csv', index = False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34578 entries, 0 to 34577
# Data columns (total 5 columns):
# Star                        34578 non-null object
# HJD-2400000.0               34578 non-null float64
# Magnitude                   34578 non-null float64
# Uncertainty in Magnitude    34578 non-null float64
# Passband                    34578 non-null object
# dtypes: float64(3), object(2)
# memory usage: 1.3+ MB
#    Star  HJD-2400000.0  Magnitude  Uncertainty in Magnitude Passband
# 0  V001   2.457833e+06     20.986                     0.022        g
# 1  V001   2.457833e+06     20.994                     0.022        g
# 2  V001   2.457833e+06     21.005                     0.022        g
# 3  V001   2.457833e+06     20.988                     0.022        g
# 4  V001   2.457833e+06     20.989                     0.022        g

# %%
best_period_crater_V001 = find_best_period(crater_photometry_new, star = 'V001', version = 'astropy')[2];
print(f"\nBest Period is {best_period_crater_V001} Days")
# Out:
# Best Period is 0.7634763476347635 Days

# %%
phase_light_curve(best_period_crater_V001, crater_photometry_new, passband = 'g', star = 'V001');

# %%
crater_best_periods = np.array(pickle.load(open("Crater II/crater_periods.pkl", "rb")))[:, 2:].T[0]

crater_periods_new = crater_periods_new.astype({'Period (Days)' : 'float64'})
crater_periods_new['Best Period (Days)'] = crater_best_periods
crater_periods_new = crater_periods_new[['Star', 'Period (Days)', 'Best Period (Days)', 'Type']]
display(crater_periods_new.head())

print(np.average(np.abs(crater_periods_new.iloc[:, 2] - crater_periods_new.iloc[:, 1])))
# Out:
#    Star  Period (Days)  Best Period (Days) Type
# 0  V001        0.76343            0.763478   AC
# 1  V002        0.60442            0.604486   ab
# 2  V003        0.60078            0.600885   ab
# 3  V004        0.41651            1.476977    d
# 4  V005        0.59900            0.599195   ab
# 0.06326453005914674

# %%
sns.scatterplot(data = crater_periods_new, x = 'Period (Days)', y = 'Best Period (Days)', 
                hue = crater_pulsation['Type'])
plt.title('Comparison of Computed and Reported Periods')
plt.xlabel('Reported Period (Days)')
plt.ylabel('Computed Period (Days)');

# %% [markdown]
# # Application to IC1613

# %%
ic_path_1 = os.path.join('IC1613', 'apj335928t4_mrt.txt')

ic_names_1 = ['Star', 'Type', 'RA (Hour)', 'RA (Min)', 'RA (Sec)', 'Dec (Deg)', 'Dec (Min)', 'Dec (Sec)',
                 'Uncertainty Flag', 'Period (Days)', 'Log Period (Days)', 'F475W Magnitude', 'F475W Amplitude', 
                 'F814W Magnitude', 'F814W Amplitude', 'Color', 'B Magnitude', 'B Amplitude', 
                 'V Magnitude', 'V Amplitude', 'I Magnitude', 'I Amplitude']

ic_pulsation = pd.read_csv(ic_path_1, sep = '\s{1,}', header = None, names = ic_names_1, engine = 'python')
ic_pulsation.head()
# Out:
#    Star Type  RA (Hour)  RA (Min)  RA (Sec)  Dec (Deg)  Dec (Min)  Dec (Sec)  \
# 0  V001   ab          1         4     20.90          2         10       36.8
# 1  V002    c          1         4     20.96          2         10       27.4
# 2  V003   EB          1         4     20.99          2          9       41.6
# 3  V004    c          1         4     22.03          2          9       10.7
# 4  V005   ab          1         4     22.10          2          9       13.1
#
#   Uncertainty Flag  Period (Days)     ...       F475W Amplitude  \
# 0                -          0.592     ...                 1.170
# 1                -          0.425     ...                 0.465
# 2                u          2.900     ...                 0.168
# 3                -          0.314     ...                 0.361
# 4                -          0.484     ...                 0.978
#
#    F814W Magnitude  F814W Amplitude  Color  B Magnitude  B Amplitude  \
# 0           24.562            0.555  0.710       25.374        1.280
# 1           24.459            0.239  0.618       25.163        0.508
# 2           23.572            0.107  0.769       24.449        0.254
# 3           24.595            0.167  0.455       25.110        0.390
# 4           24.616            0.544  0.621       25.347        1.111
#
#    V Magnitude  V Amplitude  I Magnitude  I Amplitude
# 0       25.037        0.890       24.545        0.558
# 1       24.866        0.381       24.442        0.237
# 2       24.073        0.169       23.549        0.146
# 3       24.898        0.287       24.583        0.163
# 4       24.995        0.809       24.599        0.541
#
# [5 rows x 22 columns]

# %% [markdown]
# # Application to Cetus

# %%
cetus_path_1 = os.path.join('Cetus', 'apj298915t7_mrt.txt')

cetus_names_1 = ['Star', 'Type', 'RA (Hour)', 'RA (Min)', 'RA (Sec)', 'Dec (Deg)', 'Dec (Min)', 'Dec (Sec)',
                 'Uncertainty Flag', 'Period (Days)', 'Log Period (Days)', 'F475W Magnitude', 'F475W Amplitude', 
                 'F814W Magnitude', 'F814W Amplitude', 'Color', 'B Magnitude', 'B Amplitude', 
                 'V Magnitude', 'V Amplitude', 'I Magnitude', 'I Amplitude']

cetus_pulsation = pd.read_csv(cetus_path_1, sep = '\s{1,}', header = None, names = cetus_names_1, engine = 'python')
cetus_pulsation.head()
# Out:
#    Star Type  RA (Hour)  RA (Min)  RA (Sec)  Dec (Deg)  Dec (Min)  Dec (Sec)  \
# 0  V001   ab          0        26      2.73        -11          3       40.6
# 1  V002    d          0        26      2.77        -11          3       53.2
# 2  V003   ab          0        26      2.84        -11          4       36.3
# 3  V004   ab          0        26      3.00        -11          3       40.4
# 4  V005   ab          0        26      3.07        -11          6        8.2
#
#   Uncertainty Flag Period (Days)     ...     F475W Amplitude  F814W Magnitude  \
# 0                -         0.664     ...               0.624           24.465
# 1                u         0.386     ...               0.828           24.571
# 2                -         0.591     ...               1.150           24.533
# 3                -         0.638     ...               0.569           24.493
# 4                -         0.601     ...               1.069           24.568
#
#   F814W Amplitude  Color B Magnitude  B Amplitude  V Magnitude V Amplitude  \
# 0           0.354  0.844      25.438        0.683       25.023       0.562
# 1           0.509  0.710      25.379        0.911       25.045       0.671
# 2           0.600  0.783      25.431        1.264       25.059       0.841
# 3           0.274  0.849      25.473        0.641       25.055       0.475
# 4           0.468  0.775      25.459        1.186       25.083       0.857
#
#    I Magnitude I Amplitude
# 0       24.450       0.378
# 1       24.555       0.507
# 2       24.516       0.610
# 3       24.478       0.281
# 4       24.556       0.466
#
# [5 rows x 22 columns]

# %% [markdown]
# # Application to Tucana

# %%
tucana_path_1 = os.path.join('Tucana', 'apj298915t8_mrt.txt')

tucana_names_1 = ['Star', 'Type', 'RA (Hour)', 'RA (Min)', 'RA (Sec)', 'Dec (Deg)', 'Dec (Min)', 'Dec (Sec)',
                 'Uncertainty Flag', 'Period (Days)', 'Log Period (Days)', 'F475W Magnitude', 'F475W Amplitude', 
                 'F814W Magnitude', 'F814W Amplitude', 'Color', 'B Magnitude', 'B Amplitude', 
                 'V Magnitude', 'V Amplitude', 'I Magnitude', 'I Amplitude']

tucana_pulsation = pd.read_csv(tucana_path_1, sep = '\s{1,}', header = None, names = tucana_names_1, engine = 'python')
tucana_pulsation.head()
# Out:
#    Star Type  RA (Hour)  RA (Min)  RA (Sec)  Dec (Deg)  Dec (Min)  Dec (Sec)  \
# 0  V001    d         22        41     30.84        -64         24       47.8
# 1  V002    c         22        41     31.70        -64         25        1.7
# 2  V003   ab         22        41     32.00        -64         24       57.2
# 3  V004    c         22        41     33.05        -64         25       31.9
# 4  V005   ab         22        41     33.74        -64         25        4.2
#
#   Uncertainty Flag Period (Days)     ...     F475W Amplitude  F814W Magnitude  \
# 0                u         0.370     ...               0.958           24.972
# 1                -         0.341     ...               0.650           24.992
# 2                -         0.627     ...               1.089           24.769
# 3                -         0.372     ...               0.528           24.888
# 4                -         0.543     ...               1.359           24.939
#
#   F814W Amplitude  Color B Magnitude  B Amplitude  V Magnitude V Amplitude  \
# 0           0.523  0.679      25.749        1.058       25.429       0.757
# 1           0.321  0.607      25.689        0.717       25.389       0.523
# 2           0.469  0.727      25.620        1.132       25.222       1.001
# 3           0.308  0.667      25.653        0.559       25.325       0.462
# 4           0.684  0.674      25.725        1.464       25.364       1.152
#
#    I Magnitude I Amplitude
# 0       24.955       0.513
# 1       24.976       0.318
# 2       24.751       0.472
# 3       24.870       0.325
# 4       24.923       0.684
#
# [5 rows x 22 columns]

# %% [markdown]
# # Application to Globular Clusters

# %%
NGC_5824_path = os.path.join('Globular Clusters', 'NGC5824.csv')

NGC_5824_names = ['Star', 'Type', 'Period (Days)', 'B Magnitude', 'V Magnitude', 'I Magnitude']

NGC_5824_pulsation = pd.read_csv(NGC_5824_path, header = None, names = NGC_5824_names)
NGC_5824_pulsation.head()
# Out:
#   Star  Type Period (Days)  B Magnitude  V Magnitude  I Magnitude
# 0   V1  RRab      0.597259        18.80        18.37        17.77
# 1   V2  RRab      0.649413        18.85        18.39        17.75
# 2   V3  RRab      0.732079        18.90        18.30        17.60
# 3   V4   RRc      0.334383        18.80        18.40        17.86
# 4   V5  RRab      0.630958        18.88        18.37        17.71

# %%
M4_path = os.path.join('Globular Clusters', 'M4.txt')

M4_names = ['Star', 'Period (Days)', 'U Magnitude', 'B Magnitude', 'V Magnitude', 'R Magnitude', 'I Magnitude', 
            'U Amplitude', 'B Amplitude', 'V Amplitude', 'R Amplitude', 'I Amplitude', 'Type']

M4_pulsation = pd.read_csv(M4_path, sep = '\s{1,}', header = None, names = M4_names, engine = 'python')
M4_pulsation.head()
# Out:
#   Star  Period (Days)  U Magnitude  B Magnitude  V Magnitude R Magnitude  \
# 0   V1       0.288883        14.56        14.02        13.43       13.00
# 1   V2       0.535682        14.50        14.12        13.41       12.91
# 2   V3       0.506678        14.71        13.65        13.01         â€”
# 3   V5       0.622401        14.57        14.12        13.37       12.84
# 4   V6       0.320515        14.41        14.08        13.45       13.00
#
#   I Magnitude U Amplitude B Amplitude V Amplitude R Amplitude I Amplitude  \
# 0       12.54        0.44        0.57        0.44        0.36        0.24
# 1       12.39        1.09        1.26        0.96        0.76        0.61
# 2       12.28         â€”        0.99         â€”         â€”         â€”
# 3       12.28         â€”        0.43        0.33        0.26        0.20
# 4       12.50        0.63        0.56        0.43        0.35        0.25
#
#     Type
# 0    RRc
# 1  RRab*
# 2   RRab
# 3   RRab
# 4    RRc

# %%
NGC_362_path = os.path.join('Globular Clusters', 'NGC362.txt')

NGC_362_names = ['Star', 'RA', 'Dec', 'Period (Days)', 'V Magnitude', 'Color (V - I)', 'Amplitude', 'Epoch', 'Type']

NGC_362_pulsation = pd.read_csv(NGC_362_path, sep = '\s{1,}', header = None, names = NGC_362_names, engine = 'python')
NGC_362_pulsation.head()
# Out:
#   Star          RA            Dec  Period (Days)  V Magnitude  Color (V - I)  \
# 0   V6  1:01:49.14  âˆ’71:07:36.9        0.30250        18.96           0.71
# 1   V7  1:01:54.55  âˆ’70:46:59.7        0.54753        15.80          -0.12
# 2   V8  1:01:56.71  âˆ’71:10:00.2        0.29218        19.33           0.83
# 3  V15  1:02:24.02  âˆ’70:51:56.4        0.58506        15.55           0.58
# 4  V16  1:02:24.06  âˆ’71:05:13.5        0.59339        16.47           0.11
#
#    Amplitude      Epoch  Type
# 0       1.07  3284.1702  RRab
# 1       1.32  2854.2440  RRab
# 2       0.98  3284.1647  RRab
# 3       0.91  2927.0715  RRab
# 4       0.25  2927.1882   RRc

# %% [markdown]
# # Catalog of Galaxies

# %%
galaxies_path = os.path.join('Periods', 'galaxies.txt')

galaxies_names = ['Galaxy Name', 'Apparent V Magnitude', 'Error in Magnitude']

galaxies_table = pd.read_csv(galaxies_path, sep = ',', header = None, names = galaxies_names, engine = 'python')
galaxies_table.info()
display(galaxies_table)
galaxies_table.to_csv('Monte Carlo/galaxies.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 3 columns):
# Galaxy Name             10 non-null object
# Apparent V Magnitude    10 non-null float64
# Error in Magnitude      10 non-null float64
# dtypes: float64(2), object(1)
# memory usage: 320.0+ bytes
#         Galaxy Name  Apparent V Magnitude  Error in Magnitude
# 0       Andromeda I                 12.70                0.10
# 1      Andromeda II                 11.70                0.20
# 2     Andromeda III                 14.40                0.30
# 3      Andromeda XV                 14.60                0.30
# 4  Andromeda XXVIII                 15.60                0.90
# 5             Cetus                 13.20                0.20
# 6         Crater II                 20.35                0.02
# 7           IC 1613                  9.20                0.10
# 8          Sculptor                  8.60                0.50
# 9            Tucana                 15.20                0.20
